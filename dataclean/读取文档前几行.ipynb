# %% [markdown]
# # 读取文档前几行

# %%
import os

# %%
# mxdPath = "/Users/sunlu/Workspaces/PyCharm/Github/wiki_zh_word2vec/wiki.zh.txt"
mxdPath = "/Users/sunlu/Workspaces/PyCharm/PythonDiary/data/subFileTest"
fpa=open(mxdPath)
txt = []
indexx=0
for linea in fpa.readlines():
    indexx=indexx+1
    txt = txt + [linea]
    if indexx ==5:
        break
fpa.close()
print txt
# Out:
# ['1\n', '2\n', '3\n', '4\n', '5\n']

# %%
filePath = "/Users/sunlu/Workspaces/PyCharm/Github/wiki_zh_word2vec/wiki.zh.text.vector"
fpa = open(filePath)
txt = []
indexx=0
for linea in fpa.readlines():
    indexx=indexx+1
    txt = txt + [linea.decode('utf-8').encode('utf-8')]
    if indexx ==2:
        break
fpa.close()
print txt
# Out:
# ['785943 400\n', '\xe7\x9a\x84 0.276404 0.136404 0.825536 0.312868 -1.558334 0.002207 0.951076 0.434165 1.070705 0.105925 -0.079846 0.306343 -1.378855 -1.431312 -0.803846 -1.346147 -1.149045 -1.179404 1.449409 -1.723998 -1.360457 -0.210119 -0.158164 -0.683638 2.696528 0.286591 1.473986 0.541572 1.471251 0.398980 0.765090 -0.555524 0.624417 -0.465209 0.347068 1.198181 -0.106698 -0.673462 -1.095448 0.472115 0.196981 -1.573659 -1.261058 -0.054813 -0.427257 0.769091 -0.116664 -0.724584 1.128557 0.138187 -0.325458 -0.225112 0.465138 -0.345404 -0.404246 -0.195638 -0.180304 -1.763166 0.093259 0.821030 -0.602667 1.258042 -1.122250 -0.982802 -0.479127 -1.354752 -1.887277 0.068836 0.089301 0.466705 0.737559 -0.758312 0.580855 1.245091 0.276352 -0.365365 3.404103 0.505814 1.367278 0.192436 -1.332041 -0.995321 0.290078 1.278352 0.674516 0.376660 -0.693173 -1.024162 1.174952 -0.394630 -0.094234 -0.544997 0.677625 -1.305150 -0.255014 -0.520009 0.066497 0.660533 -0.794032 -1.485078 -0.722465 -0.115
# ...

# %%
filePath = "/Users/sunlu/Workspaces/PyCharm/Github/LSTM-CNN-CWS/char_vec.txt"
fpa = open(filePath)
txt = []
indexx=0
for linea in fpa.readlines():
    indexx=indexx+1
    txt = txt + [linea.decode('utf-8').encode('utf-8')]
    if indexx ==2:
        break
fpa.close()
print txt
# Out:
# ['5691 50\n', '</s> 0.008005 0.008839 -0.007661 -0.006556 0.002733 0.006042 0.001882 0.000423 -0.007207 0.004437 -0.008713 0.002499 -0.001503 -0.001914 -0.006631 -0.003764 0.005159 0.006051 0.005938 0.003195 0.003090 -0.007605 -0.008192 0.009939 0.007603 0.006180 -0.001208 0.008031 -0.000990 0.001469 -0.000298 -0.005966 0.002625 -0.002675 -0.007651 0.009508 0.008759 -0.002190 -0.000452 0.001018 -0.007275 -0.008014 0.009109 0.000126 -0.005165 -0.006084 -0.006153 0.003394 0.000403 0.002662 \n']
