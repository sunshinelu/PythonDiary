# %%
from lxml import etree

# %%
s = """<div class="vF_detail_content"> 
 <div align="center">
  <input type="hidden" name="UnitId" size="30" maxsize="50" value="200013434" class="textbox">威海市文登区环境卫生管理处餐厨垃圾车公开招标公告
 </div>
 <div align="center">
  <input type="hidden" name="BuyKind" size="30" maxsize="50" value="01" class="textbox">
  <input type="hidden" name="NoticeType" size="30" value="0" class="textbox">
 </div>一、采购人：
 <input type="hidden" name="UnitCode" size="30" maxsize="50" value="200203" class="textbox">威海市文登区环境卫生管理处&nbsp;&nbsp;&nbsp;&nbsp;地址：威海市文登区棋山路6号(威海市文登区环境卫生管理处)&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;联系方式：8937911(威海市文登区环境卫生管理处)&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;采购代理机构：
 <input type="hidden" name="AgentCode" size="30" maxsize="50" value="37100332" class="textbox">威海市公共资源交易中心文登分中心&nbsp;&nbsp;&nbsp;&nbsp;地址：山东省威海市文登区县（区）世纪大道80号一楼&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;联系方式：06318989508二、采购项目名称：威海市文登区环境卫生管理处餐厨垃圾车&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;采购项目编号（采购计划编号）：SDGP371003201901000049&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;采购项目分包情况：
 <table id="NoticeDetail" cellspacing="0" cellpadding="1" width="100%" style="border-collapse: collapse" border="1">
  <tbody>
   <tr>
    <td align="center">标包</td>
    <td align="center">货物服务名称</td>
    <td align="center">数量</td>
    <td align="center">投标人资格要求</td>
    <td align="center">本包预算金额（最高限价，单位：万元）</td>
   </tr>
   <tr>
    <td align="center" height="30">A</td>
    <td align="center">详见采购文件&nbsp;</td>
    <td align="center">3&nbsp;</td>
    <td align="center">详见采购文件&nbsp;</td>
    <td align="center">120.000000&nbsp;</td>
   </tr>
  </tbody>
 </table>三、需求公示（见附件）四、获取招标文件&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;1.时间：2019年6月5日8时0分至2019年6月12日17时0分（报名截止时间）（北京时间，法定节假日除外）&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;2.地点：网上下载&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;3.方式：网上下载&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;4.售价：0五、公告期限：2019年6月5日 至 2019年6月12日六、递交投标文件时间及地点&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;1.时间：2019年6月25日8时10分至2019年6月25日8时30分（北京时间）&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;2.地点：威海市文登区世纪大道80号（新一中对面，市民中心B区一楼）威海市公共资源交易中心文登分中心第2开标室七、开标时间及地点&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;1.时间：2019年6月25日8时30分（北京时间）&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;2.地点：威海市文登区世纪大道80号（新一中对面，市民中心B区一楼）威海市公共资源交易中心文登分中心第2开标室八、采购项目联系方式：&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;联系人：张军&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;联系方式：06318989508
 <input type="hidden" name="LinkMan" size="10" value="张军">
 <input type="hidden" name="LinkTel" size="10" value="06318989508">九、采购项目的用途、数量、简要技术要求等
 <br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;详见采购文件十、采购项目需要落实的政府采购政策
 <br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;详见采购文件 
</div>"""
html=etree.HTML(s)
print(html)

selector=etree.HTML(s)
html_data = selector.xpath('//a/text()')
for i in html_data:
    print(i.encode('utf-8'))
# Out:
# <Element html at 0x108a91088>

# %%
s = """






<script>
var ids = [['200612668', 'A1包对应招标文件一册：第一册 村镇建设核查评估竞争性磋商文件定稿.doc', 'http://www.ccgp-shandong.gov.cn/sdgp2017/upload/attach/20190604144504_2000107813.doc'],['200612669', 'A1包对应招标文件二册：第二册 村镇建设核查评估 竞争性磋商文件定稿.doc', 'http://www.ccgp-shandong.gov.cn/sdgp2017/upload/attach/20190604144516_2000107813.doc'],['200612670', 'A2包对应招标文件一册：第一册 村镇建设核查评估竞争性磋商文件定稿.doc', 'http://www.ccgp-shandong.gov.cn/sdgp2017/upload/attach/20190604144524_2000107813.doc'],['200612671', 'A2包对应招标文件二册：第二册 村镇建设核查评估 竞争性磋商文件定稿.doc', 'http://www.ccgp-shandong.gov.cn/sdgp2017/upload/attach/20190604144536_2000107813.doc']];
</script>

<html>
<head>
<meta http-equiv="Content-Language" content="zh-cn">
<meta http-equiv="Content-Type" content="text/html; charset=gb2312">
<link rel="stylesheet" type="text/css" href="css/slide.css" />
<script type="text/javascript" src="js/js_QD/koala.min.1.5.js"></script>
<script type="text/javascript" src="js/js_QD/js.js"></script>
<title>山东省政府采购信息公开平台</title>
    <style type="text/css">
        <!--
        @import url("css/style.css");
        .whole {
            background-color: #e5e5e5;
            margin-left: 0px;
            margin-top: 0px;
            margin-right: 0px;
            margin-bottom: 0px;
        }
        -->
    </style>
<script>
function init()
{
    var nyw= 0;
    var str1="";
    if(ids.length>0){
        str1 = "附件：<br>";
    }
    for (i = 0; i < ids.length; i ++) {
        if(ids[i][2].indexOf("123.233.119.251")>-1){
            str1 = str1 + "<a href='"+ids[i][2]+"' target='_blank'>"+ids[i][1]+"</a><br>";
        }else{
                var addr = ids[i][2];
                str1 = str1 + "<a href='"+addr+"' target='_blank'>"+ids[i][1]+"</a><br>";
        }
    }
    if(document.getElementById("file_list")!="undefined") {
        document.getElementById("file_list").innerHTML = str1;
    }
    if("旧网站迁移"=="徐菲"){
        document.getElementById("oldcontent").innerHTML = document.getElementById("precontent").innerText;
    }


}
function openFile(id){
    if("2506"=="0301"){ //验收的数据是存入newattach表需要用type做区别
        window.open("/sdgp2017/servlet/attach?id="+id+"&type=newattach");
    }else{
        window.open("/sdgp2017/servlet/attach?id="+id);
    }
}
function addadvice(tar)
{
	var winstyle = "channelmode,status=no,toolbar=no,menubar=no,scrollbars=yes,resizable=yes";
	var name = "";
	if(tar==1)
		name="建议录入";
	else
		name="询问录入";
    window.open("../project/addAdvice.jsp?cmd=insert&pid="+"200143033"+"&tartype="+tar+"&type=2", name, winstyle);
}
</script>
</head>

<body class="whole" onload="init()">








<script>
    function searchKey1(){
        var key = $("#subname").val();
        if(key==""){
           alert("请填写搜索条件");
        }else{
            var winstyle = "channelmode,status=no,toolbar=no,menubar=no,scrollbars=yes,resizable=yes";
            url1 = "/sdgp2017/site/listsearchall.jsp?cmd=search&subject="+key;
			url1 = encodeURI(url1);
           // window.location.href="/sdgp2017/site/listsearchall.jsp?cmd=search&subject="+key;
            msgWindow=window.open(url1, "displayWindow", winstyle);
        }

    }
</script>
<table width="100%" height="30" border="0" cellpadding="0" cellspacing="0">
  <tr>
    <td bgcolor="#454545"><table width="1000" border="0" align="center" cellpadding="0" cellspacing="0">
      <tr>
        <td class="Font9Gray">今天是：2019年6月4日 星期二</td>
        <td align="right" valign="middle"><table border="0" cellspacing="0" cellpadding="0">
        <table>
          <tr>
              <div class="date fr pic">
                  <div class="searchbox">
                      <div class="search"><a href="/sdgp2017/site/listsearchall.jsp"></a></div>
                      <input id="subname" name="subname" type="text" class="input" value="" placeholder="请输入关键字">
                      <a onclick="searchKey1()" href="#" style="float:right"><img src="images/images_QD/dl.gif" width="50" height="22"></a>
                  </div>
              </div>
          </tr>
        </table></td>
      </tr>
    </table></td>
  </tr>
</table>
<table width="100%"  border="0" cellspacing="0" cellpadding="0">
  <tr>
    <td bgcolor="#0052c7"><table width="1000" border="0" align="center" cellpadding="0" cellspacing="0">
        <tr>
        <td width="130" align="left" valign="top"><object classid="clsid:D27CDB6E-AE6D-11cf-96B8-444553540000" codebase="http://download.macromedia.com/pub/shockwave/cabs/flash/swflash.cab#version=7,0,19,0" width="1000" height="140">
          <param name="movie" value="/sdgp2017/site/images/SD_xg.swf" />
          <param name="quality" value="high" />
          <embed src="/sdgp2017/site/images/SD_xg.swf" quality="high" pluginspage="http://www.macromedia.com/go/getflashplayer" type="application/x-shockwave-flash" width="1000" height="140"></embed>
        </object></td>
        </tr>
          <tr>
            <td align="center" valign="middle" background="/sdgp2017/site/images/header/logo_bk.png"><table width="100%" border="0" cellspacing="0" cellpadding="0">
              <tr>
                <td align="center" valign="middle" ><a class="ALink" href="/sdgp2017/site/index.jsp" class="dh">首     页</a> |
                    <a class="ALink" href="/sdgp2017/site/channelall.jsp?colcode=04" class="dh">政策法规</a>  |
                    <a class="ALink" href="/sdgp2017/site/indexgmfw.jsp?colcode=99" class="dh">购买服务</a>  |
                    <a  class="ALink" href="/sdgp2017/site/listall.jsp?colcode=01" class="dh">采购新闻</a> |
                    <a class="ALink" href="/sdgp2017/site/listall.jsp?colcode=02" class="dh">通知公告</a> |
                    <a class="ALink" href="/sdgp2017/site/channelall.jsp?colcode=0301" class="dh">采购公告</a> |
                    <a class="ALink" href="/sdgp2017/site/channelallshow.jsp?colcode=2501" class="dh">信息公开</a>  |
                    <a class="ALink" href="/sdgp2017/site/listpunishmentall.jsp?colcode=1" class="dh">投诉处理</a> |
                    <a class="ALink" href="/sdgp2017/site/listguideall.jsp?colcode=2801" class="dh">办事指南</a>  |
                    <a class="ALink" href="/sdgp2017/site/listall.jsp?colcode=06" class="dh">资料下载</a>  |
                    <a class="ALink" href="/sdgp2017/login.jsp" class="dh">系统登录</a>
                </td>
              </tr>
            </table>
            </td>
            </tr>
        </table></td>
      </tr>
    </table>
<table width="1000" border="0" align="center" cellpadding="0" cellspacing="0">
    <tr>
    <td background="/sdgp2017/site/images/header/top_bk.jpg"><table width="1000" border="0" align="center" cellpadding="0" cellspacing="0">
      <tr>
        <td><table width="1000" border="0" cellspacing="0" cellpadding="0">
          <tr>
            <td width="20"><img src="/sdgp2017/site/images/header/top_01.jpg" width="20" height="20" /></td>
            <td background="/sdgp2017/site/images/header/top_02.jpg">&nbsp;</td>
            <td width="20"><img src="/sdgp2017/site/images/header/top_03.jpg" width="20" height="20" /></td>
          </tr>
        </table></td>
      </tr>
    </table></td>
  </tr>
  </table>

<table width="1000" border="0" align="center" cellpadding="0" cellspacing="0">
    <tr>
        <td bgcolor="#FFFFFF"><table width="1000" border="0" align="center" cellpadding="0" cellspacing="0">
            <tr>
                <td  align="center" valign="top"><img src="images/main/xw_bk_01.jpg" width="20" height="270" /></td>
                <td align="center" valign="top"><table width="100%" border="0" cellspacing="0" cellpadding="0">
                    <tr>
                        <td width="1000" valign="top" align="center"><table width="100%" border="0" cellspacing="0" cellpadding="0">
                            <tr>
                                <td><table width="100%" border="0" cellpadding="0" cellspacing="0" bgcolor="#FFFFFF">
                                    <tr>
                                        <td align="center" valign="top" bgcolor="#FFFFFF"><table width="90%" border="0" cellspacing="0" cellpadding="0">
                                            <tr>
                                                <td><table width="100%" border="0" cellspacing="0" cellpadding="0">
                                                    <tr>
                                                        <td height="42" align="center" valign="middle"><table width="100%" border="0" cellspacing="0" cellpadding="0">
                                                            <tr>
                                                                <td width="27"><img src="images/erji/left_A_01.jpg" width="27" height="39" /></td>
                                                                <td align="left"   height="39" valign="middle" background="images/erji/left_A_02.jpg" class="Font16White">您现在的位置：<a class='five' href='channelall.jsp?colcode=0301'>采购公告</a> >> <a class='five' href='listall.jsp?colcode=0301'>省采购公告</a></td>
                                                                <td width="10"><img src="images/erji/left_A_03.jpg" width="10" height="39" /></td>
                                                            </tr>
                                                        </table></td>
                                                    </tr>
                                                </table></td>
                                            </tr>
                                        </table></td>
                                    </tr>
                                </table></td>
                            </tr>
                            <tr>
                                <td background="images/main/table_bk_02.jpg"><img src="images/main/table_bk_02.jpg" width="10" height="10" /></td>
                            </tr>
                        </table></td>
                    </tr>
                    <tr>
                        <td align="center" valign="top"><table width="100%" border="0" cellspacing="0" cellpadding="0">
                            <tr>
                                <td width="15"><img src="images/erji/er_bk_01.jpg" width="15" height="15" /></td>
                                <td background="images/erji/er_bk_02.jpg"><img src="images/erji/er_bk_02.jpg" width="15" height="15" /></td>
                                <td width="15"><img src="images/erji/er_bk_03.jpg" width="15" height="15" /></td>
                            </tr>

                        <tr>
                                <td background="images/erji/er_bk_04.jpg">&nbsp;</td>
                                <td bgcolor="#FFFFFF" align="center"><table width="100%" border="0" cellspacing="0" cellpadding="0">

                                    <tr>
                                        <td align="center"><b class="Font9">
                                            
                                        </b></td>
                                    </tr>
                                    <tr>
                                        <td background="images/main/table_bk_04.jpg"></td>
                                    </tr>
                                    <tr>
                                        <td class="aa">

                                            
                                            <tr><td colspan=2 align=center><div align=center><input type='hidden' name='UnitId' size='30' maxsize='50' value='4164' class=textbox>村镇建设核查评估项目竞争性磋商公告</div><div align=center><input type='hidden' name='BuyKind' size='30' maxsize='50' value='11' class=textbox><input type='hidden' name='NoticeType' size='30'  value='9' class=textbox></div></td></tr><tr><td>一、采购人：<input type='hidden' name='UnitCode' size='30' maxsize='50' value='210001' class=textbox>山东省住房和城乡建设厅&nbsp;&nbsp;&nbsp;&nbsp;地址：济南市经五路纬四路46号(山东省住房和城乡建设厅)</td></tr><tr><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;联系方式：053187080827(山东省住房和城乡建设厅)</td></tr><tr><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;采购代理机构：<input type='hidden' name='AgentCode' size='30' maxsize='50' value='195' class=textbox>山东省建设监理咨询有限公司&nbsp;&nbsp;&nbsp;&nbsp;地址：山东省济南市市中县（区）卧龙路128号23-25楼</td></tr><tr><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;联系方式：0531-87063538</td></tr><tr><td>二、采购项目名称：村镇建设核查评估项目</td></tr><tr><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;采购项目编号（采购计划编号）：SDGP370000201902002249</td></tr><tr><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;采购项目分包情况：</td></tr><tr><td valign=top><table id='NoticeDetail' cellspacing='0'cellpadding='1' width='100%' style='border-collapse: collapse' border='1'><tr><td align='center'>标包</td><td align='center'>货物服务名称</td><td align='center'>数量</td><td align='center'>投标人资格要求</td><td align='center'>本包预算金额（最高限价，单位：万元）</td></tr><tr><td align=center height=30>A1</td><td align=center>全省农村无害化卫生厕所改造完成情况核查及研究&nbsp;</td><td align=center>1&nbsp;</td><td align=center>详见竞争性磋商文件&nbsp;<td align=center>100.000000&nbsp;</td></tr><tr><td align=center height=30>A2</td><td align=center>全省农村危房改造完成情况核查及研究&nbsp;</td><td align=center>1&nbsp;</td><td align=center>详见竞争性磋商文件&nbsp;<td align=center>50.000000&nbsp;</td></tr></table></td></tr><tr><td>三、获取磋商文件</td></tr><tr><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;1.时间：2019年6月5日9时0分至2019年6月12日16时30分（报名截止时间）（北京时间，法定节假日除外）</td></tr><tr><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;2.地点：山东省建设监理咨询有限公司(济南市市中区卧龙路128号2413室)</td></tr><tr><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;3.方式：自行购买。购买时须提交下列证书原件（企业法人营业执照或事业单位法人证书副本、法人代表证或法人授权委托书、受托人身份证等“供应商的资格要求”规定提交相关证明材料，根据每包的实际要求为准。）。同时提交相应资料复印件一套（A4纸装订）并加盖公章。到山东省建设监理咨询有限公司(济南市市中区卧龙路128号2413室)报名并领取竞争性磋商文件（报名审核不代表资格审查的最终通过或合格）。供应商请访问中国山东政府采购网，在报名截止前注册并登录后进行网上投标报名。未在网上报名或网上报名不成功的，无资格进行投标（或谈判）。</td></tr>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<tr><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;4.售价：300元/份，文件售后不退</td></tr><tr><td>四、公告期限：2019年6月5日 至 2019年6月10日</td></tr><tr><td>五、递交响应文件时间及地点<tr><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;1.时间：2019年6月17日8时30分至2019年6月17日9时0分（北京时间）</td></tr><tr><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;2.地点：山东省建设监理咨询有限公司25楼会议室（济南市市中区卧龙路128号建筑节能大厦）。</td></tr><tr><td>六、磋商时间及地点<tr><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;1.时间：2019年6月17日9时0分（北京时间）</td></tr><tr><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;2.地点：山东省建设监理咨询有限公司25楼会议室（济南市市中区卧龙路128号建筑节能大厦）。</td></tr><tr><td>七、采购项目联系方式：</td></tr><tr><td>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;联系人：徐菲&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;联系方式：0531-87063538<input type='hidden' name='LinkMan' size='10' readonly value='徐菲' ><input type='hidden' name='LinkTel' size='10' readonly value='0531-87063538' ></td></tr><tr><td>八、采购项目的用途、数量、简要技术要求等<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;详见文件</td></tr><tr><td>九、采购项目需要落实的政府采购政策<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;详见文件</td></tr>
                                            

                                        </td>
                                    </tr>
                                    <tr>
                                        <td height="20"><span id="file_list"></span></td>
                                    </tr>
                                    <tr>
                                        <td height="20" align="right" class="Font9">发布人：徐菲</td>
                                    </tr>
                                    <tr>
                                        <td height="20" align="right" class="Font9">发布时间：2019年06月04日 15时03分06秒</td>
                                    </tr>
                                    <tr>
                                        <td background="images/main/table_bk_04.jpg"></td>
                                    </tr>
                                    <tr>
                                        <td height="30"><b class="lg">
                                            <img border="0" src="images/huan.jpg" width="11" height="11">&nbsp; 相关信息</b>
                                            
                                        </td>



                                    </tr>
                                    <tr><td><img src='images/arrow4.gif' width='7' height='5'><a href='readneed.jsp?id=19039'>1、山东省住房和城乡建设厅村镇建设核查评估需求公开</a></td></tr>
<tr><td><img src='images/arrow4.gif' width='7' height='5'><a href='read.jsp?id=201083448'>2、村镇建设核查评估项目竞争性磋商公告</a></td></tr>

                              </table></td>
                                <td background="images/erji/er_bk_05.jpg">&nbsp;</td>
                            </tr>
                            <tr>
                                <td><img src="images/erji/er_bk_06.jpg" width="15" height="15" /></td>
                                <td background="images/erji/er_bk_07.jpg"><img src="images/erji/er_bk_07.jpg" width="15" height="15" /></td>
                                <td><img src="images/erji/er_bk_08.jpg" width="15" height="15" /></td>
                            </tr>
                        </table></td>
                    </tr>
                </table></td>
                <td width="20" align="center" valign="top"><img src="images/main/xw_bk_01.jpg" width="20" height="270" /></td>
            </tr>
        </table>
        </td>
    </tr>
</table>










<table width="100%" border="0" cellspacing="0" cellpadding="0">
  <tr>
    <td height="10" bgcolor="#454545"></td>
  </tr>
    <tr>
        <td height="90" align="center" valign="middle" bgcolor="#0052c7">
                
            <table>
                <tr>
                     
                    <td align="center"  class="Font12blue"><script type="text/javascript">document.write(unescape("%3Cspan id='_ideConac' %3E%3C/span%3E%3Cscript src='http://dcs.conac.cn/js/16/000/0000/60412587/CA160000000604125870005.js' type='text/javascript'%3E%3C/script%3E"));</script></td>
                    <td align="right">
                        <script id="_jiucuo_" sitecode='3700000025' src='http://pucha.kaipuyun.cn/exposure/jiucuo.js'></script>
                    </td>
                    
                </tr>
                <tr>
                    <td align="center"  class="Font12blue" style="padding-top: 20px;">山东省财政厅政府采购监督管理处版权所有 &nbsp;&nbsp;&nbsp;&nbsp;网站来访统计：6729874</td>
                 </tr>
                <tr>
                    <td align="center" class="Font12blue" style="padding-bottom: 20px;">建议将显示器设置在1040*768分辨率ie8.0以上浏览&nbsp;鲁ICP备09104516号-2</td>
                </tr>
            </table>
            
        </td>
    </tr>
</table>

<script>
    function addFavorite2() {
        var url = window.location;
        var title = document.title;
        var ua = navigator.userAgent.toLowerCase();
        if (ua.indexOf("360se") > -1) {
            alert("由于360浏览器功能限制，请按 Ctrl+D 手动收藏！");
        }
        else if (ua.indexOf("msie 8") > -1) {
            window.external.AddToFavoritesBar(url, title); //IE8
        }
        else if (document.all) {
            try{
                window.external.addFavorite(url, title);
            }catch(e){
                alert('您的浏览器不支持,请按 Ctrl+D 手动收藏!');
            }
        }
        else if (window.sidebar) {
            window.sidebar.addPanel(title, url, "");
        }
        else {
            alert('您的浏览器不支持,请按 Ctrl+D 手动收藏!');
        }
    }
</script>


</body>

</html>

"""

# %%
html=etree.HTML(s)
result = etree.tostring(html)
html_data = html.xpath('//a/@href')
print(result)
# Out:
# b'<html><head><script>\nvar ids = [[\'200612668\', \'A1&#21253;&#23545;&#24212;&#25307;&#26631;&#25991;&#20214;&#19968;&#20876;&#65306;&#31532;&#19968;&#20876; &#26449;&#38215;&#24314;&#35774;&#26680;&#26597;&#35780;&#20272;&#31454;&#20105;&#24615;&#30923;&#21830;&#25991;&#20214;&#23450;&#31295;.doc\', \'http://www.ccgp-shandong.gov.cn/sdgp2017/upload/attach/20190604144504_2000107813.doc\'],[\'200612669\', \'A1&#21253;&#23545;&#24212;&#25307;&#26631;&#25991;&#20214;&#20108;&#20876;&#65306;&#31532;&#20108;&#20876; &#26449;&#38215;&#24314;&#35774;&#26680;&#26597;&#35780;&#20272; &#31454;&#20105;&#24615;&#30923;&#21830;&#25991;&#20214;&#23450;&#31295;.doc\', \'http://www.ccgp-shandong.gov.cn/sdgp2017/upload/attach/20190604144516_2000107813.doc\'],[\'200612670\', \'A2&#21253;&#23545;&#24212;&#25307;&#26631;&#25991;&#20214;&#19968;&#20876;&#65306;&#31532;&#19968;&#20876; &#26449;&#38215;&#24314;&#35774;&#26680;&#26597;&#35780;&#20272;&#31454;&#20105;&#24615;&#30923;&#21830;&#25991;&#20214
# ...

# %%
s = """<a class='k' href='https://m.weibo.cn/k/%E7%A6%8F%E5%B7%9E%E8%BA%AB%E8%BE%B9%E4%BA%8B?from=feed'>#福州身边事#</a>【永泰梧桐镇果农用传统手工 制出原汁原味柿饼】<a href='https://m.weibo.cn/n/海峡都市报'>@海峡都市报</a>：秋季的福州乡村除了层林尽染，绵延无尽的斑斓美景，还有乡亲们收秋晒秋的忙碌身影。在永泰梧桐镇，山里柿子红彤彤挂满枝头，村民们趁着柿子还没软就采摘下来，开始一年一度传统手工劳作：去皮、晾晒、出霜，做成美味的柿饼。vi ​​​...<a href="/status/4040267663381680">全文</a>"""
print s.decode("utf-8")#.encode("utf-8")
# Out:
# <a class='k' href='https://m.weibo.cn/k/%E7%A6%8F%E5%B7%9E%E8%BA%AB%E8%BE%B9%E4%BA%8B?from=feed'>#福州身边事#</a>【永泰梧桐镇果农用传统手工 制出原汁原味柿饼】<a href='https://m.weibo.cn/n/海峡都市报'>@海峡都市报</a>：秋季的福州乡村除了层林尽染，绵延无尽的斑斓美景，还有乡亲们收秋晒秋的忙碌身影。在永泰梧桐镇，山里柿子红彤彤挂满枝头，村民们趁着柿子还没软就采摘下来，开始一年一度传统手工劳作：去皮、晾晒、出霜，做成美味的柿饼。vi ​​​...<a href="/status/4040267663381680">全文</a>

# %%
html=etree.HTML(s.decode("utf-8"))
print(html)
print "============"
result = etree.tostring(html)
print(result.decode("utf-8"))
print "============"
html_data = html.xpath('//a/@href')
print html_data
# Out:
# <Element html at 0x107d917a0>
# ...

# %%
# import sys  
# reload(sys)  
# sys.setdefaultencoding('utf8')

# %%
selector=etree.HTML(s.decode('utf-8'))
html_data = selector.xpath('//a/text()')
for i in html_data:
    print(i.encode('utf-8'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-faaab2c9cb14> in <module>
# ----> 1 selector=etree.HTML(s.decode('utf-8'))
#       2 html_data = selector.xpath('//a/text()')
#       3 for i in html_data:
#       4     print(i.encode('utf-8'))
#
# AttributeError: 'str' object has no attribute 'decode'

# %%
selector=etree.HTML(s.decode('utf-8'))
html_data = selector.xpath('//a//text()')
for i in html_data:
    print i.encode('utf-8')
# Out:
# #福州身边事#
# @海峡都市报
# 全文

# %%
selector=etree.HTML(s.decode('utf-8'))
html_data = selector.xpath('//text()')
for i in html_data:
    print i.encode('utf-8')
# Out:
# #福州身边事#
# 【永泰梧桐镇果农用传统手工 制出原汁原味柿饼】
# @海峡都市报
# ：秋季的福州乡村除了层林尽染，绵延无尽的斑斓美景，还有乡亲们收秋晒秋的忙碌身影。在永泰梧桐镇，山里柿子红彤彤挂满枝头，村民们趁着柿子还没软就采摘下来，开始一年一度传统手工劳作：去皮、晾晒、出霜，做成美味的柿饼。vi ​​​...
# 全文

# %%
selector=etree.HTML(s.decode('utf-8'))
html_data = selector.xpath('//text()')
s2 = ""
for i in html_data:
    s2 = s2 + i
print s2
# Out:
# #福州身边事#【永泰梧桐镇果农用传统手工 制出原汁原味柿饼】@海峡都市报：秋季的福州乡村除了层林尽染，绵延无尽的斑斓美景，还有乡亲们收秋晒秋的忙碌身影。在永泰梧桐镇，山里柿子红彤彤挂满枝头，村民们趁着柿子还没软就采摘下来，开始一年一度传统手工劳作：去皮、晾晒、出霜，做成美味的柿饼。vi ​​​...全文
