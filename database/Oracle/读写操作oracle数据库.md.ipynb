# %% [markdown]
# # 读写操作oracle数据库
#
# > 参考链接：
# >
# >
# >
# > pandas +sqlalchemy读写oracle数据库
# > <https://blog.csdn.net/walking_visitor/article/details/84023393>

# %%
from sqlalchemy import create_engine 
import pandas as pd
conn_oracle = create_engine("oracle://system:system@localhost:1521/gongdan",encoding='utf-8', echo=True)
ls_sql = 'SELECT * FROM ml_info_item'

# %%
from sqlalchemy import create_engine 
import pandas as pd
conn_oracle = create_engine("oracle://system:system@localhost:1521/gongdan",encoding='utf-8', echo=True)
ls_sql = 'SELECT * FROM ml_info_item'
# read data to a pandas DataFrame from a SQL query:
df_t = pd.read_sql(ls_sql, conn_oracle)
print(df_t)
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# ~/anaconda2/envs/python36/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2261         try:
# -> 2262             return fn()
#    2263         except dialect.dbapi.Error as e:
#
# ~/anaconda2/envs/python36/lib/python3.6/site-packages/sqlalchemy/pool/base.py in connect(self)
#     353         if not self._use_threadlocal:
# --> 354             return _ConnectionFairy._checkout(self)
#     355
#
# ~/anaconda2/envs/python36/lib/python3.6/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     750         if not fairy:
# --> 751             fairy = _ConnectionRecord.checkout(pool)
#     752
#
# ~/anaconda2/envs/python36/lib/python3.6/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     482     def checkout(cls, pool):
# ...
