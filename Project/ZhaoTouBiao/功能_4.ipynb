# %%
#!/usr/bin/python
# -*- coding: utf-8 -*-
#不忽略weight
from pyecharts import Graph#引用之前要先pip install pyecharts及相关的支持模块
from pyecharts import WordCloud
import pandas as pd
from sqlalchemy import create_engine
# %matplotlib inline
import matplotlib
from matplotlib import pyplot as plt
# 初始化数据库连接，使用pymysql模块
# MySQL的用户：root, 密码:147369, 端口：3306,数据库：test
engine = create_engine('mysql+pymysql://root:123456@localhost:3306/test')
# 查询语句，选出employee表中的所有数据
sql = ''' select institutional_name,relevant_name,weight from test_04 where institutional_name = '大连理工招标代理有限公司'; '''
# read_sql_query的两个参数: sql语句， 数据库连接
df = pd.read_sql_query(sql, engine)
# 输出employee表的查询结果
print(df)
    
nodes = [{"name": "大连理工招标代理有限公司", "symbolSize": 30},#注意图标的位置要用绝对地址，否则会认不到图片
         {"name": df.loc[0, 'relevant_name'], "symbolSize": df.loc[0, 'weight']},#设置节点及节点图标大小
         {"name": df.loc[1, 'relevant_name'], "symbolSize": df.loc[1, 'weight']*2},
         {"name": df.loc[2, 'relevant_name'], "symbolSize": df.loc[2, 'weight']*2},
         {"name": df.loc[3, 'relevant_name'], "symbolSize": df.loc[3, 'weight']*2},
         {"name": df.loc[4, 'relevant_name'], "symbolSize": df.loc[4, 'weight']*2},
         {"name": df.loc[5, 'relevant_name'], "symbolSize": df.loc[5, 'weight']*2},
         {"name": df.loc[6, 'relevant_name'], "symbolSize": df.loc[6, 'weight']*2},
         {"name": df.loc[7, 'relevant_name'], "symbolSize": df.loc[7, 'weight']*2},
         {"name": df.loc[8, 'relevant_name'], "symbolSize": df.loc[8, 'weight']*2},
         {"name": df.loc[9, 'relevant_name'], "symbolSize": df.loc[9, 'weight']*2}
          ]
links = [{"source": "大连理工招标代理有限公司", "target": df.loc[0, 'relevant_name']},#设置节点连接关系
         {"source": "大连理工招标代理有限公司", "target": df.loc[1, 'relevant_name']},
         {"source": "大连理工招标代理有限公司", "target": df.loc[2, 'relevant_name']},
         {"source": "大连理工招标代理有限公司", "target": df.loc[3, 'relevant_name']},
         {"source": "大连理工招标代理有限公司", "target": df.loc[4, 'relevant_name']},
         {"source": "大连理工招标代理有限公司", "target": df.loc[5, 'relevant_name']},
         {"source": "大连理工招标代理有限公司", "target": df.loc[6, 'relevant_name']},
         {"source": "大连理工招标代理有限公司", "target": df.loc[7, 'relevant_name']},
         {"source": "大连理工招标代理有限公司", "target": df.loc[8, 'relevant_name']},
         {"source": "大连理工招标代理有限公司", "target": df.loc[9, 'relevant_name']}
          ]
 
graph = Graph("大连理工招标代理有限公司合作关系图",height=600,width=800)#画布高600宽800
graph.add("", nodes, links, symbol='triangle', line_color='grey',label_pos='bottom',label_text_size=11,label_text_color='black',repulsion=8000,is_label_show=True)#is_label_show=True表示节点名字为一直显示
#graph.show_config()#表示将生成的文件打印出来，我们只要结果的HTML不需要知道代码
graph
# Out:
#   institutional_name      relevant_name  weight
# 0       大连理工招标代理有限公司         中国大连高级经理学院       2
# 1       大连理工招标代理有限公司       中国烟草总公司大连市公司       1
# 2       大连理工招标代理有限公司     中国科学院大连化学物理研究所       2
# 3       大连理工招标代理有限公司     交通银行股份有限公司大连分行       2
# 4       大连理工招标代理有限公司             大连民族大学       1
# 5       大连理工招标代理有限公司             大连理工大学      10
# 6       大连理工招标代理有限公司   大连银行股份有限公司第一中心支行       1
# 7       大连理工招标代理有限公司   大连银行股份有限公司第三中心支行       1
# 8       大连理工招标代理有限公司   大连银行股份有限公司第四中心支行       1
# 9       大连理工招标代理有限公司  江西省中科院大连化物所中药科学中心       1
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="3b15abb85f5d4c569cdcd6191e48d39e" style="width:800px;height:600px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# ...

# %%
#!/usr/bin/python
# -*- coding: utf-8 -*-
#忽略weight
from pyecharts import Graph#引用之前要先pip install pyecharts及相关的支持模块
from pyecharts import WordCloud
import pandas as pd
from sqlalchemy import create_engine
# %matplotlib inline
import matplotlib
from matplotlib import pyplot as plt
# 初始化数据库连接，使用pymysql模块
# MySQL的用户：root, 密码:147369, 端口：3306,数据库：test
engine = create_engine('mysql+pymysql://root:123456@localhost:3306/test')
# 查询语句，选出employee表中的所有数据
sql = ''' select institutional_name,relevant_name,weight from test_04 where institutional_name = '大连理工招标代理有限公司'; '''
# read_sql_query的两个参数: sql语句， 数据库连接
df = pd.read_sql_query(sql, engine)
# 输出employee表的查询结果
print(df)
    
nodes = [{"name": "大连理工招标代理有限公司", "symbolSize": 30},#注意图标的位置要用绝对地址，否则会认不到图片
         {"name": df.loc[0, 'relevant_name'], "symbolSize": 20},#设置节点及节点图标大小
         {"name": df.loc[1, 'relevant_name'], "symbolSize": 20},
         {"name": df.loc[2, 'relevant_name'], "symbolSize": 20},
         {"name": df.loc[3, 'relevant_name'], "symbolSize": 20},
         {"name": df.loc[4, 'relevant_name'], "symbolSize": 20},
         {"name": df.loc[5, 'relevant_name'], "symbolSize": 20},
         {"name": df.loc[6, 'relevant_name'], "symbolSize": 20},
         {"name": df.loc[7, 'relevant_name'], "symbolSize": 20},
         {"name": df.loc[8, 'relevant_name'], "symbolSize": 20},
         {"name": df.loc[9, 'relevant_name'], "symbolSize": 20}
          ]
links = [{"source": "大连理工招标代理有限公司", "target": df.loc[0, 'relevant_name']},#设置节点连接关系
         {"source": "大连理工招标代理有限公司", "target": df.loc[1, 'relevant_name']},
         {"source": "大连理工招标代理有限公司", "target": df.loc[2, 'relevant_name']},
         {"source": "大连理工招标代理有限公司", "target": df.loc[3, 'relevant_name']},
         {"source": "大连理工招标代理有限公司", "target": df.loc[4, 'relevant_name']},
         {"source": "大连理工招标代理有限公司", "target": df.loc[5, 'relevant_name']},
         {"source": "大连理工招标代理有限公司", "target": df.loc[6, 'relevant_name']},
         {"source": "大连理工招标代理有限公司", "target": df.loc[7, 'relevant_name']},
         {"source": "大连理工招标代理有限公司", "target": df.loc[8, 'relevant_name']},
         {"source": "大连理工招标代理有限公司", "target": df.loc[9, 'relevant_name']}
          ]
 
graph = Graph("大连理工招标代理有限公司合作关系图",height=600,width=800)#画布高600宽800
graph.add("", nodes, links, symbol='triangle', line_color='grey',label_pos='bottom',label_text_size=11,label_text_color='black',repulsion=8000,is_label_show=True)#is_label_show=True表示节点名字为一直显示
#graph.show_config()#表示将生成的文件打印出来，我们只要结果的HTML不需要知道代码
graph
# Out:
#   institutional_name      relevant_name  weight
# 0       大连理工招标代理有限公司         中国大连高级经理学院       2
# 1       大连理工招标代理有限公司       中国烟草总公司大连市公司       1
# 2       大连理工招标代理有限公司     中国科学院大连化学物理研究所       2
# 3       大连理工招标代理有限公司     交通银行股份有限公司大连分行       2
# 4       大连理工招标代理有限公司             大连民族大学       1
# 5       大连理工招标代理有限公司             大连理工大学      10
# 6       大连理工招标代理有限公司   大连银行股份有限公司第一中心支行       1
# 7       大连理工招标代理有限公司   大连银行股份有限公司第三中心支行       1
# 8       大连理工招标代理有限公司   大连银行股份有限公司第四中心支行       1
# 9       大连理工招标代理有限公司  江西省中科院大连化物所中药科学中心       1
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="57bf8afc759d47989d78109355b5e29f" style="width:800px;height:600px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# ...
