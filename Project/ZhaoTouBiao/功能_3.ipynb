# %%
from pyecharts import WordCloud
import pandas as pd
from sqlalchemy import create_engine
# %matplotlib inline
import matplotlib
from matplotlib import pyplot as plt
# 初始化数据库连接，使用pymysql模块
# MySQL的用户：root, 密码:147369, 端口：3306,数据库：test
engine = create_engine('mysql+pymysql://root:123456@localhost:3306/test')
# 查询语句，选出employee表中的所有数据
sql = ''' select institutional_name,word,count from test_05 where institutional_name='中牟县教育体育局'; '''
# read_sql_query的两个参数: sql语句， 数据库连接
df = pd.read_sql_query(sql, engine)
# 输出employee表的查询结果
print(df)
name = df['word']
value = df['count'] 
wordcloud = WordCloud(width=1300, height=620)
wordcloud.add("", name, value, word_size_range=[20, 100])

wordcloud
# Out:
#    institutional_name  word  count
# 0            中牟县教育体育局  2019     17
# 1            中牟县教育体育局    下设      1
# 2            中牟县教育体育局    中小     10
# 3            中牟县教育体育局   中小学     10
# 4            中牟县教育体育局    中心      3
# 5            中牟县教育体育局    中标      5
# 6            中牟县教育体育局    中牟     23
# 7            中牟县教育体育局   中牟县     23
# 8            中牟县教育体育局    仪器      1
# 9            中牟县教育体育局  仪器设备      1
# 10           中牟县教育体育局     体      2
# 11           中牟县教育体育局    体育      3
# 12           中牟县教育体育局   体育局      3
# 13           中牟县教育体育局    公办      1
# 14           中牟县教育体育局    公告     20
# 15           中牟县教育体育局    公寓      2
# 16           中牟县教育体育局   公寓床      2
# 17           中牟县教育体育局    公设      1
# 18           中牟县教育体育局    关于      3
# 19           中牟县教育体育局    办公      2
# 20           中牟县教育体育局   办公桌      1
# 21           中牟县教育体育局  办公设备      1
# 22           中牟县教育体育局    化生      1
# 23           中牟县教育体育局    博士      2
# 24           中牟县教育体育局     及      5
# 25           中牟县教育体育局    变更      3
# 26           中牟县教育体育局    器材      2
# 27           中牟县教育体育局    图书      1
# 28           中牟县教育体育局    地下      1
# 29           中牟县教育体育局    学学      2
# ..                ...   ...    ...
# 41           中牟县教育体育局     庄      3
# 42           中牟县教育体育局    延期      1
# 43           中牟县教育体育局    心理      1
# 44           中牟县教育体育局    招标      4
# 45           中牟县教育体育局    教师      1
# 46           中牟县教育体育局    教育      3
# 47           中牟县教育体育局    新建      4
# 48           中牟县教育体育局     朱      2
# 49           中牟县教育体育局    桌椅      2
# 50           中牟县教育体育局    班班      4
# 51           中牟县教育体育局    理化      1
# 52           中牟县教育体育局   理化生      1
# 53           中牟县教育体育局    生地      1
# 54           中牟县教育体育局    监控      2
# 55           中牟县教育体育局    社区      4
# 56           中牟县教育体育局    续建      2
# 57           中牟县教育体育局     美      2
# 58           中牟县教育体育局    职教      3
# 59           中牟县教育体育局    设备     18
# 60           中牟县教育体育局    课桌      2
# 61           中牟县教育体育局   课桌凳      2
# 62           中牟县教育体育局    购置     17
# 63           中牟县教育体育局     通      4
# 64           中牟县教育体育局     郭      3
# 65           中牟县教育体育局    采购      8
# 66           中牟县教育体育局     间      1
# 67           中牟县教育体育局     音      2
# 68           中牟县教育体育局    项目      3
# 69           中牟县教育体育局    餐桌      1
# 70           中牟县教育体育局   餐桌椅      1
#
# [71 rows x 3 columns]
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'wordcloud': '/nbextensions/echarts/echarts-wordcloud.min'
#         }
#     });
# </script>
#     <div id="222b11aa6f8b4a909b2b15d5cb55bb2a" style="width:1300px;height:620px;"></div>
#
#
# <script>
#     require(['echarts', 'wordcloud'], function(echarts) {
#
# var myChart_222b11aa6f8b4a909b2b15d5cb55bb2a = echarts.init(document.getElementById('222b11aa6f8b4a909b2b15d5cb55bb2a'), 'light', {renderer: 'canvas'});
#
# var option_222b11aa6f8b4a909b2b15d5cb55bb2a = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 5133933,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "2019",
#                     "value": 17,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(159,103,23)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0b\u8bbe",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(111,103,91)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e2d\u5c0f",
#                     "value": 10,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(129,50,53)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e2d\u5c0f\u5b66",
#                     "value": 10,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(94,65,149)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e2d\u5fc3",
#                     "value": 3,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(111,148,99)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e2d\u6807",
#                     "value": 5,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(61,40,104)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e2d\u725f",
#                     "value": 23,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(20,136,29)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e2d\u725f\u53bf",
#                     "value": 23,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(110,97,61)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4eea\u5668",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(109,117,99)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4eea\u5668\u8bbe\u5907",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(150,43,40)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4f53",
#                     "value": 2,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(59,12,115)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4f53\u80b2",
#                     "value": 3,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(156,106,76)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4f53\u80b2\u5c40",
#                     "value": 3,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(112,153,116)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u516c\u529e",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(109,108,11)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u516c\u544a",
#                     "value": 20,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(56,110,146)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u516c\u5bd3",
#                     "value": 2,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(54,2,77)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u516c\u5bd3\u5e8a",
#                     "value": 2,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(160,130,133)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u516c\u8bbe",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(129,66,84)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5173\u4e8e",
#                     "value": 3,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(59,78,17)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u529e\u516c",
#                     "value": 2,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(83,98,102)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u529e\u516c\u684c",
#                     "value": 1,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(100,5,135)"
#                         }
